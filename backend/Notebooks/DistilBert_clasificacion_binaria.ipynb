# %%
# !pip install -q transformers

# %%
#Manipulacion de datos
import pandas as pd
import numpy as np

#Visualizacion
import matplotlib.pyplot as plt
import seaborn as sn

# Preprocesamiento
import spacy
from spacy.tokens import Doc
import re
from tqdm import tqdm
from typing import List
from transformers import AutoTokenizer
import torch

# Modelos
from transformers import AutoModelForSequenceClassification
from transformers import AdamW, get_linear_schedule_with_warmup
from sklearn.model_selection import train_test_split
import torch.nn as nn
from torch.optim import Adam
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix, roc_auc_score
from torch.utils.data import TensorDataset, DataLoader

# %%
#Cargar datos
data= pd.read_csv('youtoxic_english_1000.csv')

# %%
data.T
# Out:
#                                                                0    \
# CommentId                                     Ugg2KwwX0V8-aXgCoAEC
# VideoId                                                04kJtp6pVXI
# Text             If only people would just take a step back and...
# IsToxic                                                      False
# IsAbusive                                                    False
# IsThreat                                                     False
# IsProvocative                                                False
# IsObscene                                                    False
# IsHatespeech                                                 False
# IsRacist                                                     False
# IsNationalist                                                False
# IsSexist                                                     False
# IsHomophobic                                                 False
# IsReligiousHate                                              False
# IsRadicalism                                                 False
# CleanedText      If only people would just take a step back and...
#
#                                                                1    \
# CommentId                                     Ugg2s5AzSPioEXgCoAEC
# VideoId                                                04kJtp6pVXI
# Text             Law enforcement is not trained to shoot to app...
# IsToxic                                                       True
# IsAbusive                                                     True
# IsThreat                                                     False
# IsProvocative                                                False
# IsObscene                                                    False
# IsHatespeech                                                 False
# IsRacist                                                     False
# IsNationalist                                                False
# IsSexist                                                     False
# IsHomophobic                                                 False
# IsReligiousHate                                              False
# IsRadicalism                                                 False
# CleanedText      Law enforcement is not trained to shoot to app...
#
#                                                                2    \
# CommentId                                     Ugg3dWTOxryFfHgCoAEC
# VideoId                                                04kJtp6pVXI
# Text             \nDont you reckon them 'black lives matter' ba...
# IsToxic                                                       True
# IsAbusive                                                     True
# IsThreat                                                     False
# IsProvocative                                                False
# IsObscene                                                     True
# IsHatespeech                                                 False
# IsRacist                                                     False
# IsNationalist                                                False
# IsSexist                                                     False
# IsHomophobic                                                 False
# IsReligiousHate                                              False
# IsRadicalism                                                 False
# CleanedText      Dont you reckon them 'black lives matter' bann...
#
#                                                                3    \
# CommentId                                     Ugg7Gd006w1MPngCoAEC
# VideoId                                                04kJtp6pVXI
# Text             There are a very large number of people who do...
# IsToxic                                                      False
# IsAbusive                                                    False
# IsThreat                                                     False
# IsProvocative                                                False
# IsObscene                                                    False
# IsHatespeech                                                 False
# IsRacist                                                     False
# IsNationalist                                                False
# IsSexist                                                     False
# IsHomophobic                                                 False
# IsReligiousHate                                              False
# IsRadicalism                                                 False
# CleanedText      There are a very large number of people who do...
#
#                                                                4    \
# CommentId                                     Ugg8FfTbbNF8IngCoAEC
# VideoId                                                04kJtp6pVXI
# Text             The Arab dude is absolutely right, he should h...
# IsToxic                                                      False
# IsAbusive                                                    False
# IsThreat                                                     False
# IsProvocative                                                False
# IsObscene                                                    False
# IsHatespeech                                                 False
# IsRacist                                                     False
# IsNationalist                                                False
# IsSexist                                                     False
# IsHomophobic                                                 False
# IsReligiousHate                                              False
# IsRadicalism                                                 False
# CleanedText      The Arab dude is absolutely right, he should h...
#
#                                                                5    \
# CommentId                                     Ugg9a6FtoXdxmXgCoAEC
# VideoId                                                04kJtp6pVXI
# Text             here people his facebook is https://www.facebo...
# IsToxic                                                       True
# IsAbusive                                                    False
# IsThreat                                                     False
# IsProvocative                                                False
# IsObscene                                                    False
# IsHatespeech                                                  True
# IsRacist                                                     False
# IsNationalist                                                False
# IsSexist                                                     False
# IsHomophobic                                                 False
# IsReligiousHate                                               True
# IsRadicalism                                                 False
# CleanedText      here people his facebook is  he has ties with ...
#
#                                                                6    \
# CommentId                                     Ugga9KzkNDGvlXgCoAEC
# VideoId                                                04kJtp6pVXI
# Text             Check out this you tube post. "Black man goes ...
# IsToxic                                                       True
# IsAbusive                                                    False
# IsThreat                                                     False
# IsProvocative                                                False
# IsObscene                                                    False
# IsHatespeech                                                  True
# IsRacist                                                      True
# IsNationalist                                                False
# IsSexist                                                     False
# IsHomophobic                                                 False
# IsReligiousHate                                              False
# IsRadicalism                                                 False
# CleanedText      Check out this you tube post. "Black man goes ...
#
#                                                                7    \
# CommentId                                     UggBlIXoph7p-3gCoAEC
# VideoId                                                04kJtp6pVXI
# Text             I would LOVE to see this pussy go to Staten Is...
# IsToxic                                                       True
# IsAbusive                                                     True
# IsThreat                                                     False
# IsProvocative                                                False
# IsObscene                                                     True
# IsHatespeech                                                  True
# IsRacist                                                      True
# IsNationalist                                                False
# IsSexist                                                     False
# IsHomophobic                                                 False
# IsReligiousHate                                              False
# IsRadicalism                                                 False
# CleanedText      I would LOVE to see this pussy go to Staten Is...
#
#                                          8    \
# CommentId               UggD1aYSn7KOR3gCoAEC
# VideoId                          04kJtp6pVXI
# Text             I agree with the protestor.
# IsToxic                                False
# IsAbusive                              False
# IsThreat                               False
# IsProvocative                          False
# IsObscene                              False
# IsHatespeech                           False
# IsRacist                               False
# IsNationalist                          False
# IsSexist                               False
# IsHomophobic                           False
# IsReligiousHate                        False
# IsRadicalism                           False
# CleanedText      I agree with the protestor.
#
#                                                               9    ...  \
# CommentId                                    UggGm8a1fu8brngCoAEC  ...
# VideoId                                               04kJtp6pVXI  ...
# Text             mike browns father was made to say that boooshit  ...
# IsToxic                                                      True  ...
# IsAbusive                                                    True  ...
# IsThreat                                                    False  ...
# IsProvocative                                               False  ...
# IsObscene                                                    True  ...
# IsHatespeech                                                False  ...
# IsRacist                                                    False  ...
# IsNationalist                                               False  ...
# IsSexist                                                    False  ...
# IsHomophobic                                                False  ...
# IsReligiousHate                                             False  ...
# IsRadicalism                                                False  ...
# CleanedText      mike browns father was made to say that boooshit  ...
#
#                                                                987  \
# CommentId                                     Ugh07S5UNzXDWngCoAEC
# VideoId                                                XRuCW80L9mA
# Text             Remember..Michael Brown was just a young, teen...
# IsToxic                                                      False
# IsAbusive                                                    False
# IsThreat                                                     False
# IsProvocative                                                False
# IsObscene                                                    False
# IsHatespeech                                                 False
# IsRacist                                                     False
# IsNationalist                                                False
# IsSexist                                                     False
# IsHomophobic                                                 False
# IsReligiousHate                                              False
# IsRadicalism                                                 False
# CleanedText      Remember..Michael Brown was just a young, teen...
#
#                                                                988  \
# CommentId                                     Ughbo_MZ42mpJ3gCoAEC
# VideoId                                                XRuCW80L9mA
# Text             What point are you trying to make?  Is it that...
# IsToxic                                                      False
# IsAbusive                                                    False
# IsThreat                                                     False
# IsProvocative                                                False
# IsObscene                                                    False
# IsHatespeech                                                 False
# IsRacist                                                     False
# IsNationalist                                                False
# IsSexist                                                     False
# IsHomophobic                                                 False
# IsReligiousHate                                              False
# IsRadicalism                                                 False
# CleanedText      What point are you trying to make? Is it that ...
#
#                                                                989  \
# CommentId                                     Ughd_2zFh-O-93gCoAEC
# VideoId                                                XRuCW80L9mA
# Text             There are a lot of disgusting people in the co...
# IsToxic                                                      False
# IsAbusive                                                    False
# IsThreat                                                     False
# IsProvocative                                                False
# IsObscene                                                    False
# IsHatespeech                                                 False
# IsRacist                                                     False
# IsNationalist                                                False
# IsSexist                                                     False
# IsHomophobic                                                 False
# IsReligiousHate                                              False
# IsRadicalism                                                 False
# CleanedText      There are a lot of disgusting people in the co...
#
#                                                                990  \
# CommentId                                     UghGyVemEvDEqXgCoAEC
# VideoId                                                XRuCW80L9mA
# Text             Whites should move-out of Ferguson, let's see ...
# IsToxic                                                       True
# IsAbusive                                                    False
# IsThreat                                                     False
# IsProvocative                                                False
# IsObscene                                                    False
# IsHatespeech                                                  True
# IsRacist                                                      True
# IsNationalist                                                False
# IsSexist                                                     False
# IsHomophobic                                                 False
# IsReligiousHate                                              False
# IsRadicalism                                                 False
# CleanedText      Whites should move-out of Ferguson, let's see ...
#
#                                                                991  \
# CommentId                                     UghHMimNd9cYxngCoAEC
# VideoId                                                XRuCW80L9mA
# Text             I just found this channel and its one of my fa...
# IsToxic                                                      False
# IsAbusive                                                    False
# IsThreat                                                     False
# IsProvocative                                                False
# IsObscene                                                    False
# IsHatespeech                                                 False
# IsRacist                                                     False
# IsNationalist                                                False
# IsSexist                                                     False
# IsHomophobic                                                 False
# IsReligiousHate                                              False
# IsRadicalism                                                 False
# CleanedText      I just found this channel and its one of my fa...
#
#                                                                992  \
# CommentId                                     Ugi5ADt10EdDz3gCoAEC
# VideoId                                                XRuCW80L9mA
# Text             I remember that they sent in the national defe...
# IsToxic                                                      False
# IsAbusive                                                    False
# IsThreat                                                     False
# IsProvocative                                                False
# IsObscene                                                    False
# IsHatespeech                                                 False
# IsRacist                                                     False
# IsNationalist                                                False
# IsSexist                                                     False
# IsHomophobic                                                 False
# IsReligiousHate                                              False
# IsRadicalism                                                 False
# CleanedText      I remember that they sent in the national defe...
#
#                                                                993  \
# CommentId                                     Ugifh2DMhBbDkHgCoAEC
# VideoId                                                XRuCW80L9mA
# Text             Stats don`t represent the problem. Race baitin...
# IsToxic                                                       True
# IsAbusive                                                    False
# IsThreat                                                     False
# IsProvocative                                                False
# IsObscene                                                    False
# IsHatespeech                                                  True
# IsRacist                                                      True
# IsNationalist                                                False
# IsSexist                                                     False
# IsHomophobic                                                 False
# IsReligiousHate                                              False
# IsRadicalism                                                 False
# CleanedText      Stats don`t represent the problem. Race baitin...
#
#                                                                994  \
# CommentId                                     Ugj_plbGBjjzYXgCoAEC
# VideoId                                                XRuCW80L9mA
# Text             The quote from the mother... Wow that hit hard...
# IsToxic                                                      False
# IsAbusive                                                    False
# IsThreat                                                     False
# IsProvocative                                                False
# IsObscene                                                    False
# IsHatespeech                                                 False
# IsRacist                                                     False
# IsNationalist                                                False
# IsSexist                                                     False
# IsHomophobic                                                 False
# IsReligiousHate                                              False
# IsRadicalism                                                 False
# CleanedText      The quote from the mother... Wow that hit hard...
#
#                                      995  \
# CommentId           Ugj0bah1De8xy3gCoAEC
# VideoId                      XRuCW80L9mA
# Text             this video is so racist
# IsToxic                            False
# IsAbusive                          False
# IsThreat                           False
# IsProvocative                      False
# IsObscene                          False
# IsHatespeech                       False
# IsRacist                           False
# IsNationalist                      False
# IsSexist                           False
# IsHomophobic                       False
# IsReligiousHate                    False
# IsRadicalism                       False
# CleanedText      this video is so racist
#
#                                                            996
# CommentId                                 UgjBJKQSoQMQ6ngCoAEC
# VideoId                                            XRuCW80L9mA
# Text             God, the narrator has such an annoying lisp.
# IsToxic                                                  False
# IsAbusive                                                False
# IsThreat                                                 False
# IsProvocative                                            False
# IsObscene                                                False
# IsHatespeech                                             False
# IsRacist                                                 False
# IsNationalist                                            False
# IsSexist                                                 False
# IsHomophobic                                             False
# IsReligiousHate                                          False
# IsRadicalism                                             False
# CleanedText       God, the narrator has such an annoying lisp.
#
# [16 rows x 997 columns]

# %% [markdown]
# # **ETIQUETA**

# %%
# Consolidar las etiquetas en una sola columna binaria 'IsHate'
# Creación de una nueva columna 'IsHate'
hate_columns = ['IsToxic', 'IsAbusive', 'IsThreat', 'IsProvocative', 'IsObscene', 'IsHatespeech',
                'IsRacist', 'IsNationalist', 'IsSexist', 'IsHomophobic', 'IsReligiousHate', 'IsRadicalism']

# Un comentario es considerado de odio si cumple cualquiera de las condiciones anteriores
data['IsHate'] = data[hate_columns].any(axis=1)

# Ahora seleccionamos solo las columnas necesarias, es decir, 'Text' y 'IsHate'
data_simplified = data[['Text', 'IsHate']]

# Verificamos la distribución de las clases
distribution = data_simplified['IsHate'].value_counts()

data_simplified.head(), distribution
# Out:
# (                                                Text  IsHate
#  0  If only people would just take a step back and...   False
#  1  Law enforcement is not trained to shoot to app...    True
#  2  \nDont you reckon them 'black lives matter' ba...    True
#  3  There are a very large number of people who do...   False
#  4  The Arab dude is absolutely right, he should h...   False,
#  False    538
#  True     462
#  Name: IsHate, dtype: int64)

# %%
# Dividir los datos en conjuntos de entrenamiento y prueba
train_data, test_data = train_test_split(data_simplified, test_size=0.2, random_state=42)

# %% [markdown]
# # **PREPROCESAMIENTO**

# %%
# Tokenizador
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")

# %%
# Codificación de los datos de entrenamiento
train_encoding = tokenizer(train_data['Text'].tolist(), padding=True, truncation=True, max_length=128, return_tensors="pt")
train_labels = torch.tensor(train_data['IsHate'].values, dtype=torch.long)

# %%
# Codificación de los datos de prueba
test_encoding = tokenizer(test_data['Text'].tolist(), padding=True, truncation=True, max_length=128, return_tensors="pt")
test_labels = torch.tensor(test_data['IsHate'].values, dtype=torch.long)

# %% [markdown]
# # **MODELO**

# %%
# Modelo y optimizador con regularización L2 (weight_decay)LO VAMOS AJUSTANDO
model = AutoModelForSequenceClassification.from_pretrained("distilbert-base-uncased", num_labels=2)
optimizer = AdamW(model.parameters(), lr=5e-5, weight_decay=0.01)  # Ajusta el valor de weight_decay según sea necesario
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=len(train_data))
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'classifier.bias', 'classifier.weight', 'pre_classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
# Datasets y Dataloaders
train_dataset = TensorDataset(train_encoding.input_ids, train_encoding.attention_mask, train_labels)
test_dataset = TensorDataset(test_encoding.input_ids, test_encoding.attention_mask, test_labels)

train_dataloader = DataLoader(train_dataset, batch_size=8, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=8, shuffle=False)

# %%
# Definir la función de pérdida y el dispositivo (GPU o CPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
loss_fn = nn.CrossEntropyLoss()

# %%
# Número de épocas y entrenamiento
num_epochs = 2

for epoch in range(num_epochs):
    # Entrenamiento
    model.train()
    total_loss = 0.0
    correct_predictions = 0
    total_samples = 0

    for batch in train_dataloader:
        input_ids, attention_mask, labels = batch
        input_ids, attention_mask, labels = input_ids.to(device), attention_mask.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(input_ids, attention_mask=attention_mask)
        logits = outputs.logits
        loss = loss_fn(logits, labels)
        total_loss += loss.item()

        # Calcular la precisión en el conjunto de entrenamiento
        preds = torch.argmax(logits, dim=1)
        correct_predictions += torch.sum(preds == labels).item()
        total_samples += len(labels)

        loss.backward()
        optimizer.step()
        scheduler.step()

    # Calcular la pérdida promedio y la precisión en el conjunto de entrenamiento
    average_loss = total_loss / len(train_dataloader)
    train_accuracy = correct_predictions / total_samples

    print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {average_loss}, Train Accuracy: {train_accuracy}")
# Out:
# Epoch 1/2, Loss: 0.5910302184522152, Train Accuracy: 0.6775
# Epoch 2/2, Loss: 0.3781577431410551, Train Accuracy: 0.85375

# %% [markdown]
# # **EVALUACIÓN DEL MODELO**

# %%
# Evaluación en el conjunto de prueba
model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for batch in test_dataloader:
        input_ids, attention_mask, labels = batch
        input_ids, attention_mask, labels = input_ids.to(device), attention_mask.to(device), labels.to(device)

        outputs = model(input_ids, attention_mask=attention_mask)
        logits = outputs.logits
        preds = torch.argmax(logits, dim=1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# %%
# Calcular métricas de evaluación
precision = precision_score(all_labels, all_preds)
recall = recall_score(all_labels, all_preds)
f1 = f1_score(all_labels, all_preds)
test_accuracy = accuracy_score(all_labels, all_preds)
conf_matrix = confusion_matrix(all_labels, all_preds)
roc_auc = roc_auc_score(all_labels, all_preds)

print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print(f"Accuracy: {test_accuracy}")
print(f"Confusion Matrix:\n{conf_matrix}")
print(f"ROC AUC Score: {roc_auc}")
# Out:
# Precision: 0.8556701030927835
# Recall: 0.7757009345794392
# F1 Score: 0.8137254901960783
# Accuracy: 0.81
# Confusion Matrix:
# [[79 14]
#  [24 83]]
# ROC AUC Score: 0.8125816500854185

# %%
overfitting = train_accuracy - test_accuracy
print(f'Overfitting: {overfitting}')
# Out:
# Overfitting: 0.043749999999999956

# %% [markdown]
# # **GUARDAR EL MODELO**

# %%
# Save the model
model.save("model")

# %% [markdown]
# # **CARGAR EL MODELO**

# %%
#Para cargar el modelo y el tokenizador posteriormente
loaded_model = DistilBertForSequenceClassification.from_pretrained("model_directory")
loaded_tokenizer = DistilBertTokenizer.from_pretrained("model_directory")
